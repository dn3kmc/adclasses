# %%
dataset_name = "artificial_cd_3"
path = "data/" + dataset_name + ".csv"
gaussian_window_size = 128

# %%
import adclasses
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import joblib
import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.
# /home/cfreeman/Documents/NextIT/adclasses2/adclasses2_venv/lib/python3.5/site-packages/tensorflow/python/framework/ops.py:939: DeprecationWarning: builtin type EagerTensor has no __module__ attribute
#   EagerTensor = c_api.TFE_Py_InitEagerTensor(_EagerTensorBase)
# /home/cfreeman/Documents/NextIT/adclasses2/adclasses2_venv/lib/python3.5/site-packages/tensorflow/python/util/tf_inspect.py:55: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if d.decorator_argspec is not None), _inspect.getargspec(target))

# %% [markdown]
# # Preprocess dataset

# %%
data = pd.read_csv(path, header=0)
start_date = data["timestamp"].values[0]
end_date = data["timestamp"].values[-1]
print("Start date: ", start_date)
print("End date: ", end_date)

data["timestamp"] = pd.to_datetime(data["timestamp"], 
                                   format="%Y-%m-%d %H:%M:%S")

print("Missing time stamps: \n", adclasses.find_missing_time_steps(start_date, end_date, 
                                                                   '5min', data))

ad = adclasses.UnivariateAnomalyDetection(dataframe=data, 
                                          timestep="5min", 
                                          dateformat="%Y-%m-%d %H:%M:%S", 
                                          name=dataset_name)
print("Length: ", ad.get_length())
print("Time step size: ", ad.get_timestep())
print("Start Date: ", start_date)
print("End Date: ", end_date)
print("Date Format: ", ad.get_dateformat())
true_outlier_dates = ["2014-04-01 16:40:00",
                      "2014-04-02 09:20:00",
                      "2014-04-03 02:00:00",
                      "2014-04-03 18:40:00"]
true_outlier_indices = ad.convert_true_outlier_date(true_outlier_dates)
print("True outlier indices: ", true_outlier_indices)
# Out:
# Start date:  2014-04-01 00:00:00
# End date:  2014-04-04 11:15:00
# Missing time stamps:
#  DatetimeIndex([], dtype='datetime64[ns]', freq='5T')
# Length:  1000
# Time step size:  5min
# Start Date:  2014-04-01 00:00:00
# End Date:  2014-04-04 11:15:00
# Date Format:  %Y-%m-%d %H:%M:%S
# True outlier indices:  [200, 400, 600, 800]

# %% [markdown]
# # SARIMA: using autoarima

# %%
save_path = "anomaly_scores/SARIMA_auto/" + dataset_name
output_dict = ad.sarima(gaussian_window_size=gaussian_window_size,
                        autoarima=True, 
                        autoarima_season=False, 
                        plot_acf=True, 
                        maxiter=3, 
                        plot_anomaly_score=True)
print("Time: ", output_dict["Time"])
print("RMSE: ", output_dict["RMSE"])
joblib.dump(output_dict, save_path)
# Out:
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 0, 0, 1); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 1); AIC=716.882, BIC=722.903, Fit time=0.034 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 0, 1); AIC=718.878, BIC=727.910, Fit time=0.092 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 0, 1); AIC=718.878, BIC=727.909, Fit time=0.146 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 0, 1); AIC=720.887, BIC=732.930, Fit time=0.191 seconds
# Total fit time: 0.481 seconds
# Final parameters:  (0, 0, 0, 0, 0, 0, 0)
# Time:  0.8650763034820557
# RMSE:  28.778755258314682
# ['anomaly_scores/SARIMA_auto/artificial_cd_3']

# %% [markdown]
# # Facebook Prophet

# %%
save_path = "anomaly_scores/Prophet/" + dataset_name
output_dict = ad.facebook_prophet(gaussian_window_size=gaussian_window_size,periods=0, interval_width=.999, plot_anomaly_score=True)
print("Time: ", output_dict["Time"])
print("RMSE: ", output_dict["RMSE"])
joblib.dump(output_dict, save_path)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# Time:  6.027956485748291
# RMSE:  3.6624619673250085
# ['anomaly_scores/Prophet/artificial_cd_3']

# %% [markdown]
# # RNN

# %%
save_path = "anomaly_scores/RNN/" + dataset_name
output_dict = ad.rnn(gaussian_window_size=gaussian_window_size,n_lag=100, n_seq=5, n_test=20, n_epochs=50,
                     n_batch=1, n_neurons=40, training_index=int(.15 * ad.get_length()), plot_anomaly_score=True)
print("Time: ", output_dict["Time"])
joblib.dump(output_dict, save_path)
# Out:
# Time:  33.23424243927002
# ['anomaly_scores/RNN/artificial_cd_3']

# %%
save_path = "anomaly_scores/RNN/" + dataset_name
output_dict = ad.rnn(gaussian_window_size=gaussian_window_size,n_lag=100, n_seq=50, n_test=20, n_epochs=50,
                     n_batch=1, n_neurons=40, training_index=int(.15 * ad.get_length()), plot_anomaly_score=True)
print("Time: ", output_dict["Time"])
joblib.dump(output_dict, save_path)
# Out:
# Time:  45.326685190200806
# ['anomaly_scores/RNN/artificial_cd_3']

# %% [markdown]
# # HTM

# %%
htm_results_path = "htm_studio_results/" + "htm_results_" + dataset_name + "_value.csv"
htm_results = pd.read_csv(htm_results_path, header=0)

plt.plot(htm_results["raw_anomaly_score"], color="black", label="anomaly score")
plt.legend()
plt.xticks(rotation=90)
plt.show()

anomaly_scores = np.nan_to_num(htm_results["raw_anomaly_score"].values)

save_path = "anomaly_scores/HTM/" + dataset_name
print("Time: ", "11.19")
output_dict = {"Anomaly Scores": anomaly_scores, "Time": "11.19"}
joblib.dump(output_dict, save_path)
# Out:
# Time:  11.19
# ['anomaly_scores/HTM/artificial_cd_3']

# %% [markdown]
# # Donut

# %%
save_path = "anomaly_scores/Donut/" + dataset_name
output_dict = ad.donut(gaussian_window_size=gaussian_window_size,window_size=20, plot_reconstruction_prob=True, plot_anomaly_score=True)
print("Time: ", output_dict["Time"])
joblib.dump(output_dict, save_path)
# Out:
# Trainable Parameters              (27,950 in total)
# ---------------------------------------------------
# donut/p_x_given_z/x_mean/bias    (20,)           20
# donut/p_x_given_z/x_mean/kernel  (100, 20)    2,000
# donut/p_x_given_z/x_std/bias     (20,)           20
# donut/p_x_given_z/x_std/kernel   (100, 20)    2,000
# donut/q_z_given_x/z_mean/bias    (5,)             5
# donut/q_z_given_x/z_mean/kernel  (100, 5)       500
# donut/q_z_given_x/z_std/bias     (5,)             5
# donut/q_z_given_x/z_std/kernel   (100, 5)       500
# sequential/_0/dense/bias         (100,)         100
# sequential/_0/dense/kernel       (5, 100)       500
# sequential/_1/dense/bias         (100,)         100
# sequential/_1/dense/kernel       (100, 100)  10,000
# sequential_1/_0/dense/bias       (100,)         100
# sequential_1/_0/dense/kernel     (20, 100)    2,000
# sequential_1/_1/dense/bias       (100,)         100
# sequential_1/_1/dense/kernel     (100, 100)  10,000
#
# [Epoch 10/256, Step 0, ETA 0.2968s] Learning rate decreased to 0.00075
# [Epoch 20/256, Step 0, ETA 0.195s] Learning rate decreased to 0.0005625000000000001
# [Epoch 30/256, Step 0, ETA 0.1594s] Learning rate decreased to 0.00042187500000000005
# [Epoch 40/256, Step 0, ETA 0.1355s] Learning rate decreased to 0.00031640625000000006
# [Epoch 50/256, Step 0, ETA 0.114s] Learning rate decreased to 0.00023730468750000005
# [Epoch 60/256, Step 0, ETA 0.09895s] Learning rate decreased to 0.00017797851562500002
# [Epoch 70/256, Step 0, ETA 0.08825s] Learning rate decreased to 0.00013348388671875002
# [Epoch 80/256, Step 0, ETA 0.08134s] Learning rate decreased to 0.00010011291503906251
# [Epoch 90/256, Step 0, ETA 0.07325s] Learning rate decreased to 7.508468627929689e-05
# [Epoch 100/256, Step 0, ETA 0.06598s] Learning rate decreased to 5.631351470947266e-05
# [Epoch 110/256, Step 0, ETA 0.05962s] Learning rate decreased to 4.22351360321045e-05
# [Epoch 120/256, Step 0, ETA 0.05386s] Learning rate decreased to 3.167635202407837e-05
# [Epoch 130/256, Step 0, ETA 0.04865s] Learning rate decreased to 2.3757264018058778e-05
# [Epoch 140/256, Step 0, ETA 0.04383s] Learning rate decreased to 1.7817948013544083e-05
# [Epoch 150/256, Step 0, ETA 0.03952s] Learning rate decreased to 1.3363461010158061e-05
# [Epoch 160/256, Step 0, ETA 0.03645s] Learning rate decreased to 1.0022595757618546e-05
# [Epoch 170/256, Step 0, ETA 0.0332s] Learning rate decreased to 7.51694681821391e-06
# [Epoch 180/256, Step 0, ETA 0.02984s] Learning rate decreased to 5.637710113660432e-06
# [Epoch 190/256, Step 0, ETA 0.02629s] Learning rate decreased to 4.228282585245324e-06
# [Epoch 200/256, Step 0, ETA 0.02272s] Learning rate decreased to 3.171211938933993e-06
# [Epoch 210/256, Step 0, ETA 0.0189s] Learning rate decreased to 2.3784089542004944e-06
# [Epoch 220/256, Step 0, ETA 0.01498s] Learning rate decreased to 1.7838067156503708e-06
# [Epoch 230/256, Step 0, ETA 0.011s] Learning rate decreased to 1.337855036737778e-06
# [Epoch 240/256, Step 0, ETA 0.006969s] Learning rate decreased to 1.0033912775533336e-06
# [Epoch 250/256, Step 0, ETA 0.002847s] Learning rate decreased to 7.525434581650002e-07
# Time:  3.437776803970337
# ['anomaly_scores/Donut/artificial_cd_3']

# %% [markdown]
# # windowed Gaussian

# %%
save_path = "anomaly_scores/windowed_gaussian/" + dataset_name
output_dict = ad.windowed_gaussian(gaussian_window_size=gaussian_window_size,plot_anomaly_score=True)
print("Time: ", output_dict["Time"])
joblib.dump(output_dict, save_path)
# Out:
# Time:  0.16716575622558594
# ['anomaly_scores/windowed_gaussian/artificial_cd_3']

# %% [markdown]
# # HOTSAX

# %%
save_path = "anomaly_scores/hotsax/" + dataset_name
output_dict = ad.hotsax(win_size=50, num_discords=2,
               a_size=3, paa_size=3, z_threshold=0.01,
               plot_anomaly_score=True)
print("Time: ", output_dict["Time"])
joblib.dump(output_dict, save_path)
# Out:
# Time:  13.749905347824097
# ['anomaly_scores/hotsax/artificial_cd_3']

# %%
# no twitter bc no seasonality
# no stl bc no seasonality
