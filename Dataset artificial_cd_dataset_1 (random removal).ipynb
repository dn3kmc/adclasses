# %%
dataset_name = "artificial_cd_1_random_removal"
path = "data/" + dataset_name + ".csv"
gaussian_window_size = 1024

# %%
import adclasses
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import joblib
import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.
# /home/cfreeman/Documents/NextIT/adclasses2/adclasses2_venv/lib/python3.5/site-packages/tensorflow/python/framework/ops.py:939: DeprecationWarning: builtin type EagerTensor has no __module__ attribute
#   EagerTensor = c_api.TFE_Py_InitEagerTensor(_EagerTensorBase)
# /home/cfreeman/Documents/NextIT/adclasses2/adclasses2_venv/lib/python3.5/site-packages/tensorflow/python/util/tf_inspect.py:55: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if d.decorator_argspec is not None), _inspect.getargspec(target))

# %% [markdown]
# # Preprocess Dataset

# %%
data = pd.read_csv(path, header=0)
start_date = data["timestamp"].values[0]
end_date = data["timestamp"].values[-1]
print("Start date: ", start_date)
print("End date: ", end_date)

data["timestamp"] = pd.to_datetime(data["timestamp"], 
                                   format="%Y-%m-%d %H:%M:%S")

print("Missing time stamps: \n", adclasses.find_missing_time_steps(start_date, end_date, 
                                                                   '5min', data))

ad = adclasses.UnivariateAnomalyDetection(dataframe=data, 
                                          timestep="5min", 
                                          dateformat="%Y-%m-%d %H:%M:%S", 
                                          name=dataset_name)
print("Length: ", ad.get_length())
print("Time step size: ", ad.get_timestep())
print("Start Date: ", start_date)
print("End Date: ", end_date)
print("Date Format: ", ad.get_dateformat())
true_outlier_dates = ["2014-04-01 16:40:00",
                      "2014-04-02 09:20:00",
                      "2014-04-03 02:00:00"]
true_outlier_indices = ad.convert_true_outlier_date(true_outlier_dates)
print("True outlier indices: ", true_outlier_indices)
# Out:
# Start date:  2014-04-01 00:00:00
# End date:  2014-04-03 18:35:00
# Missing time stamps:
#  DatetimeIndex(['2014-04-02 05:40:00', '2014-04-02 16:40:00',
#                '2014-04-03 12:50:00', '2014-04-03 12:55:00'],
#               dtype='datetime64[ns]', freq=None)
# WARNING: There are missing time steps. This restricts the kinds of anomaly detection methods that can be used. See fill_missing_time_steps
# Length:  800
# Time step size:  5min
# Start Date:  2014-04-01 00:00:00
# End Date:  2014-04-03 18:35:00
# Date Format:  %Y-%m-%d %H:%M:%S
# True outlier indices:  [200, 400, 600]

# %% [markdown]
# # Donut

# %%
save_path = "anomaly_scores/Donut/" + dataset_name
output_dict = ad.donut(gaussian_window_size=gaussian_window_size,window_size=20, plot_reconstruction_prob=True, plot_anomaly_score=True)
print("Time: ", output_dict["Time"])
joblib.dump(output_dict, save_path)
# Out:
# Trainable Parameters              (27,950 in total)
# ---------------------------------------------------
# donut/p_x_given_z/x_mean/bias    (20,)           20
# donut/p_x_given_z/x_mean/kernel  (100, 20)    2,000
# donut/p_x_given_z/x_std/bias     (20,)           20
# donut/p_x_given_z/x_std/kernel   (100, 20)    2,000
# donut/q_z_given_x/z_mean/bias    (5,)             5
# donut/q_z_given_x/z_mean/kernel  (100, 5)       500
# donut/q_z_given_x/z_std/bias     (5,)             5
# donut/q_z_given_x/z_std/kernel   (100, 5)       500
# sequential/_0/dense/bias         (100,)         100
# sequential/_0/dense/kernel       (5, 100)       500
# sequential/_1/dense/bias         (100,)         100
# sequential/_1/dense/kernel       (100, 100)  10,000
# sequential_1/_0/dense/bias       (100,)         100
# sequential_1/_0/dense/kernel     (20, 100)    2,000
# sequential_1/_1/dense/bias       (100,)         100
# sequential_1/_1/dense/kernel     (100, 100)  10,000
#
# [Epoch 10/256, Step 0, ETA 0.2022s] Learning rate decreased to 0.00075
# [Epoch 20/256, Step 0, ETA 0.1345s] Learning rate decreased to 0.0005625000000000001
# [Epoch 30/256, Step 0, ETA 0.1149s] Learning rate decreased to 0.00042187500000000005
# [Epoch 40/256, Step 0, ETA 0.1052s] Learning rate decreased to 0.00031640625000000006
# [Epoch 50/256, Step 0, ETA 0.09543s] Learning rate decreased to 0.00023730468750000005
# [Epoch 60/256, Step 0, ETA 0.08636s] Learning rate decreased to 0.00017797851562500002
# [Epoch 70/256, Step 0, ETA 0.0789s] Learning rate decreased to 0.00013348388671875002
# [Epoch 80/256, Step 0, ETA 0.07173s] Learning rate decreased to 0.00010011291503906251
# [Epoch 90/256, Step 0, ETA 0.06375s] Learning rate decreased to 7.508468627929689e-05
# [Epoch 100/256, Step 0, ETA 0.05683s] Learning rate decreased to 5.631351470947266e-05
# [Epoch 110/256, Step 0, ETA 0.05094s] Learning rate decreased to 4.22351360321045e-05
# [Epoch 120/256, Step 0, ETA 0.04565s] Learning rate decreased to 3.167635202407837e-05
# [Epoch 130/256, Step 0, ETA 0.04088s] Learning rate decreased to 2.3757264018058778e-05
# [Epoch 140/256, Step 0, ETA 0.03659s] Learning rate decreased to 1.7817948013544083e-05
# [Epoch 150/256, Step 0, ETA 0.03262s] Learning rate decreased to 1.3363461010158061e-05
# [Epoch 160/256, Step 0, ETA 0.02887s] Learning rate decreased to 1.0022595757618546e-05
# [Epoch 170/256, Step 0, ETA 0.02531s] Learning rate decreased to 7.51694681821391e-06
# [Epoch 180/256, Step 0, ETA 0.02195s] Learning rate decreased to 5.637710113660432e-06
# [Epoch 190/256, Step 0, ETA 0.01871s] Learning rate decreased to 4.228282585245324e-06
# [Epoch 200/256, Step 0, ETA 0.01565s] Learning rate decreased to 3.171211938933993e-06
# [Epoch 210/256, Step 0, ETA 0.01272s] Learning rate decreased to 2.3784089542004944e-06
# [Epoch 220/256, Step 0, ETA 0.009877s] Learning rate decreased to 1.7838067156503708e-06
# [Epoch 230/256, Step 0, ETA 0.007107s] Learning rate decreased to 1.337855036737778e-06
# [Epoch 240/256, Step 0, ETA 0.004414s] Learning rate decreased to 1.0033912775533336e-06
# [Epoch 250/256, Step 0, ETA 0.001794s] Learning rate decreased to 7.525434581650002e-07
# Time:  3.544304847717285
# ['anomaly_scores/Donut/artificial_cd_1_random_removal']

# %% [markdown]
# # STL Resid

# %%
# no stl bc no seasonality
